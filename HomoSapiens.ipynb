# %%
import networkx as nx
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("HomoSapiens_binary_hq (1).txt",sep="\t",usecols=["Uniprot_A","Uniprot_B"])

# %%
G=nx.from_pandas_edgelist(df,"Uniprot_A","Uniprot_B",create_using=nx.DiGraph())

# %%
degrees=dict(G.degree())
order=sorted(degrees.items(),key=lambda t:t[1])
x,y=zip(*order)
plt.plot(x,y)
plt.show()

# %%
from collections import Counter
degree_sequence = [G.degree(n) for n in G.nodes]
degree_counts = Counter(degree_sequence)
min_degree, max_degree = min(degree_counts.keys()), max(degree_counts.keys())
plt.xlabel("Degree", fontsize=20)
plt.ylabel("Number of Nodes", fontsize=20)
plot_x = list(range(min_degree, max_degree + 1))
plot_y = [degree_counts.get(x, 0) for x in plot_x]
plt.bar(plot_x, plot_y)
# Out:
# <BarContainer object of 855 artists>

# %%
import math
def plot_degree_dist(G):
    
    degrees = G.degree()
    degrees = dict(degrees)
    values = sorted(set(degrees.values()))
   
    histo = [list(degrees.values()).count(x) for x in values]
    P_k = [x / G.order() for x in histo]
   
    
    plt.figure()
    plt.bar(values, P_k)
    plt.xlabel("k",fontsize=20)
    plt.ylabel("p(k)", fontsize=20)
    plt.title("Degree Distribution", fontsize=20)
    
    plt.show()
    plt.figure()
    plt.loglog(values, P_k, "bo")
    plt.xlabel("k", fontsize=20)
    plt.ylabel("log p(k)", fontsize=20)
    plt.show()

# %%
plot_degree_dist(G)

# %%
order
# Out:
# [('A0A024R1A3', 1),
#  ('A0A024R6G0', 1),
#  ('A0A024RA58', 1),
#  ('A0A024RC46', 1),
#  ('A0A024RCL4', 1),
#  ('A0A024RCZ4', 1),
#  ('A0A087WWS6', 1),
#  ('A0A5B6', 1),
#  ('A0A0B4J272', 1),
#  ('A0A0B4J295', 1),
#  ('A0A0B4J2D5', 1),
#  ('A0A0U1RRH7', 1),
#  ('A0A126GV92', 1),
#  ('A0A1B0GTR3', 1),
#  ('A0A1W2PQS6', 1),
#  ('A0A2K7P776', 1),
#  ('A0A4E0W6L3', 1),
#  ('A0AUZ9', 1),
#  ('A0AV02', 1),
#  ('Q6IAN0', 1),
#  ('A0MSS3', 1),
#  ('Q9Y5L5', 1),
#  ('A1A4F0', 1),
#  ('A1A4G5', 1),
#  ('A1A4Y4', 1),
#  ('A1L3Z8', 1),
#  ('A2A284', 1),
#  ('A2ABK9', 1),
#  ('A2AE51', 1),
#  ('A2BHY8', 1),
#  ('A2IDD5', 1),
#  ('A2NUT2', 1),
#  ('A2RRG2', 1),
#  ('A2RRP1', 1),
#  ('A2RTY3', 1),
#  ('A2VDF0', 1),
#  ('A3R0T8', 1),
#  ('A4D1B5', 1),
#  ('A4D1F7', 1),
#  ('A4D1U4', 1),
#  ('A4D2D6', 1),
#  ('A4FU01', 1),
#  ('A4FU49', 1),
#  ('A4FU71', 1),
#  ('A4GXA9', 1),
#  ('A4QPH2', 1),
#  ('A5PLN9', 1),
#  ('Q8WY41', 1),
#  ('A5YM72', 1),
#  ('A6NCF5', 1),
#  ('A6ND48', 1),
#  ('A6ND79', 1),
#  ('A6NDN3', 1),
#  ('A6NDU8', 1),
#  ('A6NDV4', 1),
#  ('A6NE52', 1),
#  ('A6NE82', 1),
#  ('A6NED2', 1),
#  ('A6NEL2', 1),
#  ('A6NEQ2', 1),
#  ('A6NGB9', 1),
#  ('A6NGH7', 1),
#  ('A6NGK3', 1),
#  ('A6NHQ2', 1),
#  ('A6NIM6', 1),
#  ('A6NJ69', 1),
#  ('A6NK53', 1),
#  ('Q5VUB5', 1),
#  ('A6NKD2', 1),
#  ('A6NKD9', 1),
#  ('A6NKH4', 1),
#  ('A6NKK0', 1),
#  ('A6NLP3', 1),
#  ('A6NMD0', 1),
#  ('A6NMT0', 1),
#  ('A6NMX2', 1),
#  ('A6NN06', 1),
#  ('A6NN80', 1),
#  ('A6NNB3', 1),
#  ('A6NNF4', 1),
#  ('A6NNL0', 1),
#  ('A6PVS8', 1),
#  ('A6XGL0', 1),
#  ('A6XND8', 1),
#  ('A7E1Y8', 1),
#  ('A7E2F4', 1),
#  ('A8K147', 1),
#  ('A8K1V4', 1),
#  ('A8K4Y7', 1),
#  ('Q9H0M4', 1),
#  ('A8K5M4', 1),
#  ('A8K673', 1),
#  ('A8K6G4', 1),
#  ('Q8TB68', 1),
#  ('A8K8Y5', 1),
#  ('A8K900', 1),
#  ('A8K940', 1),
#  ('A8K9C1', 1),
#  ('A8KAF9', 1),
#  ('A8KAG1', 1),
#  ('P01298', 1),
#  ('Q5SW24', 1),
#  ('Q6HA08', 1),
#  ('Q8WXX7', 1),
#  ('Q9NW81', 1),
#  ('A8MRT5', 1),
#  ('Q2M3C7', 1),
#  ('A8MT70', 1),
#  ('Q6ZN32', 1),
#  ('Q9H2Z4', 1),
#  ('A8MVS5', 1),
#  ('A8MWX0', 1),
#  ('A9UF07', 1),
#  ('B0QY85', 1),
#  ('B0S7P4', 1),
#  ('B0UZY3', 1),
#  ('F8WBK4', 1),
#  ('B0YJ76', 1),
#  ('B1AHD6', 1),
#  ('UPI0001AFF976', 1),
#  ('B1AJQ0', 1),
#  ('B1AL64', 1),
#  ('B1AL88', 1),
#  ('B1ALB5', 1),
#  ('B1ALL0', 1),
#  ('B1ALV1', 1),
#  ('B1AN94', 1),
#  ('B1ANA3', 1),
#  ('B1ANN6', 1),
#  ('B1AQP4', 1),
#  ('B1AVT1', 1),
#  ('B1B0M1', 1),
#  ('F8VXF8', 1),
#  ('B2R4U6', 1),
#  ('B2R5B3', 1),
#  ('B4DR52', 1),
#  ('B2R5P6', 1),
#  ('B2R6J3', 1),
#  ('B2R7W0', 1),
#  ('B2R886', 1),
#  ('B2RAT6', 1),
#  ('B2RCP4', 1),
#  ('B2RCU6', 1),
#  ('B2RDC9', 1),
#  ('B2RDE6', 1),
#  ('F8W894', 1),
#  ('B2RMV2', 1),
#  ('B2RU30', 1),
#  ('Q86WA9', 1),
#  ('Q9Y286', 1),
#  ('B2RV13', 1),
#  ('B2RXH4', 1),
#  ('Q53HQ0', 1),
#  ('B3KPJ1', 1),
#  ('B3KPL7', 1),
#  ('B3KSN7', 1),
#  ('B3KTA1', 1),
#  ('B3KWQ7', 1),
#  ('B3KX42', 1),
#  ('B3SHH9', 1),
#  ('B4DEC9', 1),
#  ('B4DF73', 1),
#  ('B4DG68', 1),
#  ('B4DH63', 1),
#  ('B4DHB6', 1),
#  ('B4DHK7', 1),
#  ('B4DHR3', 1),
#  ('B4DIR9', 1),
#  ('Q14784', 1),
#  ('B4DJ69', 1),
#  ('B4DJP2', 1),
#  ('B4DK40', 1),
#  ('B4DLR9', 1),
#  ('B4DMB7', 1),
#  ('B4DP29', 1),
#  ('B4DR88', 1),
#  ('B4DUS4', 1),
#  ('B4DUS5', 1),
#  ('Q13402', 1),
#  ('B4DVY0', 1),
#  ('B4DW13', 1),
#  ('B4DY66', 1),
#  ('O43155', 1),
#  ('O75094', 1),
#  ('Q0VAA2', 1),
#  ('Q5BKY1', 1),
#  ('Q6P2D8', 1),
#  ('Q6P9F7', 1),
#  ('Q6UY01', 1),
#  ('Q8IUZ0', 1),
#  ('Q96DD0', 1),
#  ('Q96FV0', 1),
#  ('Q9H967', 1),
#  ('B4DZT3', 1),
#  ('B4E2X3', 1),
#  ('B6SEH8', 1),
#  ('B7Z2A4', 1),
#  ('Q546Y9', 1),
#  ('B7Z2Y6', 1),
#  ('B7Z5W0', 1),
#  ('B7Z6F4', 1),
#  ('B7Z6S9', 1),
#  ('B7Z7E0', 1),
#  ('B7Z7S1', 1),
#  ('B7Z8K6', 1),
#  ('P03986', 1),
#  ('B7Z9S8', 1),
#  ('B7ZAZ3', 1),
#  ('B7ZVW5', 1),
#  ('B9A064', 1),
#  ('B9A6J5', 1),
#  ('C9J1E8', 1),
#  ('C9J442', 1),
#  ('C9J798', 1),
#  ('C9JLW8', 1),
#  ('C9JMK7', 1),
#  ('C9JRZ8', 1),
#  ('C9K004', 1),
#  ('C9K0W8', 1),
#  ('Q5HY47', 1),
#  ('D3DV11', 1),
#  ('D3W0D1', 1),
#  ('D3YTE0', 1),
#  ('D4Q8H0', 1),
#  ('E0CX11', 1),
#  ('E2PSM9', 1),
#  ('E3W975', 1),
#  ('E5KN15', 1),
#  ('E7EMC3', 1),
#  ('E7EME8', 1),
#  ('E7EMX7', 1),
#  ('E7EPF0', 1),
#  ('E7ERL9', 1),
#  ('E7ETH6', 1),
#  ('E7ETX1', 1),
#  ('E9PAT2', 1),
#  ('E9PBI4', 1),
#  ('E9PC28', 1),
#  ('E9PC93', 1),
#  ('E9PCE5', 1),
#  ('E9PI22', 1),
#  ('F1D8S6', 1),
#  ('F2Z2H2', 1),
#  ('F2Z2H6', 1),
#  ('F5GXJ4', 1),
#  ('F5GZ44', 1),
#  ('H7C030', 1),
#  ('F5H241', 1),
#  ('F5H2Q5', 1),
#  ('H0YL21', 1),
#  ('F5H4T9', 1),
#  ('F5H5E5', 1),
#  ('F5H8M2', 1),
#  ('F6STL4', 1),
#  ('F8VPI7', 1),
#  ('F8VWE3', 1),
#  ('F8VYX6', 1),
#  ('F8VZD8', 1),
#  ('F8W6G7', 1),
#  ('F8W786', 1),
#  ('F8WEI5', 1),
#  ('G3V0F1', 1),
#  ('G3V1Q1', 1),
#  ('G3V3V0', 1),
#  ('G3V4V3', 1),
#  ('G5E988', 1),
#  ('G8H6I3', 1),
#  ('G8JLB4', 1),
#  ('G8JLL4', 1),
#  ('UPI000187F6BA', 1),
#  ('H0Y6X8', 1),
#  ('H0YG75', 1),
#  ('H0YGH3', 1),
#  ('H0YHG0', 1),
#  ('H0YJ32', 1),
#  ('H0YLM1', 1),
#  ('H3BR10', 1),
#  ('H3BRN8', 1),
#  ('H3BSY8', 1),
#  ('H3BT41', 1),
#  ('H7BXF4', 1),
#  ('H7BXP5', 1),
#  ('H7C554', 1),
#  ('H9NIM3', 1),
#  ('I3L4Q8', 1),
#  ('I3L4S8', 1),
#  ('I7GY12', 1),
#  ('K7EMQ9', 1),
#  ('J3KNK4', 1),
#  ('J3KQV0', 1),
#  ('J3QTP2', 1),
#  ('K7ENZ8', 1),
#  ('K7EPM5', 1),
#  ('K7EQW8', 1),
#  ('O00115', 1),
#  ('O00116', 1),
#  ('Q9NVA4', 1),
#  ('Q86W33', 1),
#  ('Q96BD0', 1),
#  ('Q9NVR5', 1),
#  ('O00178', 1),
#  ('O00186', 1),
#  ('Q96K76', 1),
#  ('O00192', 1),
#  ('Q9NPH5', 1),
#  ('O00220', 1),
#  ('Q7Z6B7', 1),
#  ('Q04656', 1),
#  ('Q9P0U0', 1),
#  ('O76075', 1),
#  ('P24298', 1),
#  ('Q9H8N7', 1),
#  ('O00421', 1),
#  ('O00442', 1),
#  ('O00458', 1),
#  ('Q86XP1', 1),
#  ('P31271', 1),
#  ('P35453', 1),
#  ('O00504', 1),
#  ('Q8WWX8', 1),
#  ('Q92908', 1),
#  ('O00515', 1),
#  ('O00519', 1),
#  ('Q9ULI3', 1),
#  ('Q3LXA3', 1),
#  ('Q8WXD2', 1),
#  ('Q9H5V8', 1),
#  ('V9HW40', 1),
#  ('O00562', 1),
#  ('O00625', 1),
#  ('P48506', 1),
#  ('Q6FG85', 1),
#  ('O00716', 1),
#  ('O00744', 1),
#  ('O00754', 1),
#  ('O14514', 1),
#  ('Q8N695', 1),
#  ('O14521', 1),
#  ('O14525', 1),
#  ('O14548', 1),
#  ('O14578', 1),
#  ('O14598', 1),
#  ('O14628', 1),
#  ('Q9UFH2', 1),
#  ('O14683', 1),
#  ('Q8WV83', 1),
#  ('O14715', 1),
#  ('Q9UPU7', 1),
#  ('Q9H3S5', 1),
#  ('Q16568', 1),
#  ('O14791', 1),
#  ('Q14184', 1),
#  ('O14827', 1),
#  ('O14828', 1),
#  ('Q0P5U8', 1),
#  ('Q5T764', 1),
#  ('Q8IXX5', 1),
#  ('O14894', 1),
#  ('Q9NXX6', 1),
#  ('O14904', 1),
#  ('O14921', 1),
#  ('O14924', 1),
#  ('O14950', 1),
#  ('P05015', 1),
#  ('Q8N0U4', 1),
#  ('Q96LM9', 1),
#  ('P51811', 1),
#  ('O15013', 1),
#  ('O15014', 1),
#  ('O15018', 1),
#  ('P61163', 1),
#  ('O15061', 1),
#  ('O15072', 1),
#  ('Q8TDN2', 1),
#  ('O95625', 1),
#  ('Q6NUQ4', 1),
#  ('P61916', 1),
#  ('Q0VAR9', 1),
#  ('Q8WYG9', 1),
#  ('Q86UD5', 1),
#  ('Q96L15', 1),
#  ('O60476', 1),
#  ('O75197', 1),
#  ('Q5JVG2', 1),
#  ('Q86UK5', 1),
#  ('Q8N3P4', 1),
#  ('Q8N436', 1),
#  ('Q8N4U6', 1),
#  ('Q96MK7', 1),
#  ('Q9H6V3', 1),
#  ('Q9NSV4', 1),
#  ('O15254', 1),
#  ('O15403', 1),
#  ('O15432', 1),
#  ('O15457', 1),
#  ('O15466', 1),
#  ('O15480', 1),
#  ('Q9ULS5', 1),
#  ('Q8N1M1', 1),
#  ('Q96BW5', 1),
#  ('O15527', 1),
#  ('Q8IWY9', 1),
#  ('O15551', 1),
#  ('Q9UIW2', 1),
#  ('P54845', 1),
#  ('Q6TXQ4', 1),
#  ('O43194', 1),
#  ('O43264', 1),
#  ('O43291', 1),
#  ('P49207', 1),
#  ('O43303', 1),
#  ('O43304', 1),
#  ('O43306', 1),
#  ('P98155', 1),
#  ('Q9Y4C0', 1),
#  ('O43325', 1),
#  ('Q9Y4C1', 1),
#  ('Q7Z6S6', 1),
#  ('O75940', 1),
#  ('O43396', 1),
#  ('O43405', 1),
#  ('O95260', 1),
#  ('O43490', 1),
#  ('O43497', 1),
#  ('Q08830', 1),
#  ('O43529', 1),
#  ('Q59E92', 1),
#  ('O43581', 1),
#  ('P53384', 1),
#  ('Q9BY42', 1),
#  ('Q9Y5R8', 1),
#  ('Q5JRC9', 1),
#  ('Q8TE77', 1),
#  ('Q9Y5L2', 1),
#  ('Q14390', 1),
#  ('O43731', 1),
#  ('Q9UL36', 1),
#  ('O60235', 1),
#  ('P10082', 1),
#  ('P59861', 1),
#  ('Q5DT21', 1),
#  ('Q96PD5', 1),
#  ('Q9HB09', 1),
#  ('Q9Y5B2', 1),
#  ('P52945', 1),
#  ('O43808', 1),
#  ('Q96BU1', 1),
#  ('O43819', 1),
#  ('O43823', 1),
#  ('O43825', 1),
#  ('O43826', 1),
#  ('Q9Y6Q1', 1),
#  ('Q9BS86', 1),
#  ('O75023', 1),
#  ('O94886', 1),
#  ('P16562', 1),
#  ('P48651', 1),
#  ('P56202', 1),
#  ('P62079', 1),
#  ('Q5SRD1', 1),
#  ('Q6UX01', 1),
#  ('Q8NEE0', 1),
#  ('Q9BQ16', 1),
#  ('O43903', 1),
#  ('O43915', 1),
#  ('O43921', 1),
#  ('P51160', 1),
#  ('Q92781', 1),
#  ('O43930', 1),
#  ('O60218', 1),
#  ('V9HW37', 1),
#  ('V9HW96', 1),
#  ('O60258', 1),
#  ('Q96MG8', 1),
#  ('O60284', 1),
#  ('O60299', 1),
#  ('Q9P0N5', 1),
#  ('O60331', 1),
#  ('O60337', 1),
#  ('Q3BBV0', 1),
#  ('O60346', 1),
#  ('Q59GG4', 1),
#  ('O60412', 1),
#  ('O60427', 1),
#  ('O60469', 1),
#  ('O60478', 1),
#  ('O60488', 1),
#  ('Q9BXJ7', 1),
#  ('O60500', 1),
#  ('O60518', 1),
#  ('O60536', 1),
#  ('Q5TF35', 1),
#  ('O60575', 1),
#  ('Q15399', 1),
#  ('O60637', 1),
#  ('Q86VF7', 1),
#  ('O60670', 1),
#  ('P22309', 1),
#  ('O60706', 1),
#  ('O60748', 1),
#  ('Q6ZSJ8', 1),
#  ('O60779', 1),
#  ('O60829', 1),
#  ('Q6QNK2', 1),
#  ('O60840', 1),
#  ('Q9BUU2', 1),
#  ('O60879', 1),
#  ('P41217', 1),
#  ('O60931', 1),
#  ('O60938', 1),
#  ('O95755', 1),
#  ('P30531', 1),
#  ('P41159', 1),
#  ('Q8N103', 1),
#  ('Q8WUJ3', 1),
#  ('Q9P2H3', 1),
#  ('O75061', 1),
#  ('O75078', 1),
#  ('O75096', 1),
#  ('O75123', 1),
#  ('O75144', 1),
#  ('O75153', 1),
#  ('O75161', 1),
#  ('Q68CZ1', 1),
#  ('P36402', 1),
#  ('Q5VYY1', 1),
#  ('O75182', 1),
#  ('Q9HCE9', 1),
#  ('O75271', 1),
#  ('O75290', 1),
#  ('O75323', 1),
#  ('O75325', 1),
#  ('O75347', 1),
#  ('O75365', 1),
#  ('O75368', 1),
#  ('Q6NXT1', 1),
#  ('Q6ZN11', 1),
#  ('Q8N2I2', 1),
#  ('O75387', 1),
#  ('Q6ZMG9', 1),
#  ('P24347', 1),
#  ('Q13129', 1),
#  ('Q15238', 1),
#  ('Q7Z5N4', 1),
#  ('Q9P246', 1),
#  ('O75526', 1),
#  ('P17097', 1),
#  ('Q5T9K6', 1),
#  ('Q9H098', 1),
#  ('O75544', 1),
#  ('Q6ZXV5', 1),
#  ('Q9H9I0', 1),
#  ('Q9UBR5', 1),
#  ('Q9NRM6', 1),
#  ('Q6ZT07', 1),
#  ('Q8NCJ5', 1),
#  ('Q03169', 1),
#  ('Q15269', 1),
#  ('Q5T0I1', 1),
#  ('Q92546', 1),
#  ('Q5SRE5', 1),
#  ('O75747', 1),
#  ('O75752', 1),
#  ('P20264', 1),
#  ('P61221', 1),
#  ('Q6ZNR0', 1),
#  ('O75879', 1),
#  ('O75891', 1),
#  ('O75900', 1),
#  ('P48169', 1),
#  ('O75947', 1),
#  ('O75969', 1),
#  ('Q8NEP7', 1),
#  ('Q9BQS7', 1),
#  ('Q8NDY6', 1),
#  ('Q7L4M3', 1),
#  ('Q9BWJ2', 1),
#  ('O94933', 1),
#  ('P0CG08', 1),
#  ('Q14C60', 1),
#  ('Q86UG4', 1),
#  ('Q9BTF0', 1),
#  ('Q9UK10', 1),
#  ('O76031', 1),
#  ('Q6NX55', 1),
#  ('Q96T76', 1),
#  ('O76076', 1),
#  ('Q6ZT16', 1),
#  ('O94768', 1),
#  ('O94777', 1),
#  ('O94808', 1),
#  ('O94812', 1),
#  ('O94832', 1),
#  ('O94864', 1),
#  ('P55822', 1),
#  ('O94876', 1),
#  ('O94880', 1),
#  ('O94887', 1),
#  ('Q6UXS0', 1),
#  ('O94892', 1),
#  ('O94919', 1),
#  ('Q8ND76', 1),
#  ('O94988', 1),
#  ('P0DP42', 1),
#  ('Q969M3', 1),
#  ('O95081', 1),
#  ('Q8NB37', 1),
#  ('Q8WVP7', 1),
#  ('O95239', 1),
#  ('O95249', 1),
#  ('Q8TED9', 1),
#  ('Q96MT7', 1),
#  ('Q9C0C2', 1),
#  ('P18405', 1),
#  ('Q6ZU64', 1),
#  ('Q96EH5', 1),
#  ('Q96EH8', 1),
#  ('Q59GB8', 1),
#  ('Q8IV53', 1),
#  ('Q8IYW4', 1),
#  ('O95373', 1),
#  ('P48664', 1),
#  ('Q5VYU5', 1),
#  ('Q8NB89', 1),
#  ('UPI0002590962', 1),
#  ('Q6P3W7', 1),
#  ('Q9H4A4', 1),
#  ('O95427', 1),
#  ('O95475', 1),
#  ('O95476', 1),
#  ('O95478', 1),
#  ('O95487', 1),
#  ('O95490', 1),
#  ('O95613', 1),
#  ('Q9BSD7', 1),
#  ('Q8NBI3', 1),
#  ('P13762', 1),
#  ('Q99467', 1),
#  ('O95759', 1),
#  ('P38935', 1),
#  ('Q86YB7', 1),
#  ('Q9Y597', 1),
#  ('Q9P0T5', 1),
#  ('Q8NHP7', 1),
#  ('Q6R6M4', 1),
#  ('P05177', 1),
#  ('Q9T9Y2', 1),
#  ('UPI0000411897', 1),
#  ('Q8TCB7', 1),
#  ('O95965', 1),
#  ('O95977', 1),
#  ('Q6ZNC4', 1),
#  ('P28906', 1),
#  ('Q6ZR62', 1),
#  ('P0DI82', 1),
#  ('Q8N4H5', 1),
#  ('Q8N7B1', 1),
#  ('P22310', 1),
#  ('Q9H6R6', 1),
#  ('Q12979', 1),
#  ('Q9BZM3', 1),
#  ('Q9H0X9', 1),
#  ('Q9NUR3', 1),
#  ('P31939', 1),
#  ('P49798', 1),
#  ('Q14050', 1),
#  ('Q4KWH8', 1),
#  ('Q53GZ6', 1),
#  ('Q59EJ3', 1),
#  ('Q59G22', 1),
#  ('Q59GR8', 1),
#  ('Q6UWJ1', 1),
#  ('Q69EZ8', 1),
#  ('Q96RI0', 1),
#  ('Q9UKQ2', 1),
#  ('P00995', 1),
#  ('P50052', 1),
#  ('P17927', 1),
#  ('P01036', 1),
#  ('Q92616', 1),
#  ('Q5VZX0', 1),
#  ('Q92633', 1),
#  ('Q9H0S4', 1),
#  ('Q14392', 1),
#  ('P01210', 1),
#  ('P0DN87', 1),
#  ('P01286', 1),
#  ('P01562', 1),
#  ('P01570', 1),
#  ('P01589', 1),
#  ('P01772', 1),
#  ('P01825', 1),
#  ('P47974', 1),
#  ('Q01668', 1),
#  ('Q14679', 1),
#  ('P01906', 1),
#  ('Q12794', 1),
#  ('Q9HBG4', 1),
#  ('P02818', 1),
#  ('Q5T2N8', 1),
#  ('Q8NHW5', 1),
#  ('Q9H293', 1),
#  ('P03891', 1),
#  ('P03923', 1),
#  ('P03999', 1),
#  ('P05014', 1),
#  ('Q15784', 1),
#  ('Q8NAA4', 1),
#  ('Q76LX8', 1),
#  ('P43631', 1),
#  ('P04553', 1),
#  ('P51797', 1),
#  ('Q6ZV89', 1),
#  ('Q8N6N2', 1),
#  ('Q9NZJ7', 1),
#  ('Q9Y5J1', 1),
#  ('P55199', 1),
#  ('Q8WWV6', 1),
#  ('Q96M02', 1),
#  ('P04732', 1),
#  ('P04733', 1),
#  ('P04839', 1),
#  ('P04920', 1),
#  ('P05013', 1),
#  ('Q13724', 1),
#  ('Q9H5Q2', 1),
#  ('P15086', 1),
#  ('P32745', 1),
#  ('Q5HYA8', 1),
#  ('Q8NHT4', 1),
#  ('Q16878', 1),
#  ('Q14690', 1),
#  ('P05111', 1),
#  ('Q86YJ7', 1),
#  ('P05496', 1),
#  ('P05937', 1),
#  ('P06133', 1),
#  ('Q02846', 1),
#  ('Q9BZJ6', 1),
#  ('Q96NS8', 1),
#  ('Q9H4X1', 1),
#  ('Q5TC12', 1),
#  ('Q13542', 1),
#  ('Q05707', 1),
#  ('P52926', 1),
#  ('P07099', 1),
#  ('Q6ZMW9', 1),
#  ('Q6ZUA9', 1),
#  ('P07492', 1),
#  ('Q9NYQ6', 1),
#  ('P19835', 1),
#  ('P81408', 1),
#  ('Q9BT67', 1),
#  ('P07988', 1),
#  ('Q96GJ1', 1),
#  ('Q01650', 1),
#  ('P33121', 1),
#  ('Q96HZ8', 1),
#  ('Q9H0I9', 1),
#  ('P23490', 1),
#  ('Q9H6K1', 1),
#  ('Q96EP5', 1),
#  ('Q9BQ61', 1),
#  ('Q9H3J7', 1),
#  ('Q8IZ81', 1),
#  ('Q16842', 1),
#  ('Q6ZTI4', 1),
#  ('Q9UHF5', 1),
#  ('Q9UMP7', 1),
#  ('Q8TAC1', 1),
#  ('P09131', 1),
#  ('P28370', 1),
#  ('P51991', 1),
#  ('Q96T23', 1),
#  ('Q9Y2R9', 1),
#  ('P26717', 1),
#  ('P18089', 1),
#  ('P09529', 1),
#  ('P11182', 1),
#  ('P48546', 1),
#  ('Q6UWX4', 1),
#  ('P0C5W0', 1),
#  ('P0C7M6', 1),
#  ('Q08AD1', 1),
#  ('Q6UWI4', 1),
#  ('Q99798', 1),
#  ('P0C869', 1),
#  ('Q6IEY1', 1),
#  ('Q8N127', 1),
#  ('Q8N567', 1),
#  ('P0CF51', 1),
#  ('P0CG12', 1),
#  ('P0CG24', 1),
#  ('P0CH99', 1),
#  ('P0CW23', 1),
#  ('Q3KQZ1', 1),
#  ('P0DMB1', 1),
#  ('P0DMR2', 1),
#  ('P0DMV0', 1),
#  ('Q9H2S1', 1),
#  ('Q96PH1', 1),
#  ('P23634', 1),
#  ('P0DPH9', 1),
#  ('P0DPI2', 1),
#  ('P10092', 1),
#  ('P12235', 1),
#  ('P43626', 1),
#  ('P10523', 1),
#  ('Q5JQC9', 1),
#  ('P10767', 1),
#  ('Q6P280', 1),
#  ('P11150', 1),
#  ('Q9ULI2', 1),
#  ('P11229', 1),
#  ('P11465', 1),
#  ('P11488', 1),
#  ('P28324', 1),
#  ('Q8IXL1', 1),
#  ('Q5VWC8', 1),
#  ('Q7Z3Q1', 1),
#  ('Q58A45', 1),
#  ('Q8IYD1', 1),
#  ('P24530', 1),
#  ('P50993', 1),
#  ('P52569', 1),
#  ('Q03721', 1),
#  ('Q19T08', 1),
#  ('Q495M3', 1),
#  ('Q6ZQS4', 1),
#  ('Q6ZWE6', 1),
#  ('Q711Q0', 1),
#  ('Q76M96', 1),
#  ('Q86TB3', 1),
#  ('Q86W56', 1),
#  ('Q8N699', 1),
#  ('Q8NBX0', 1),
#  ('Q8NDY8', 1),
#  ('Q92643', 1),
#  ('Q9BSK1', 1),
#  ('Q9BUM1', 1),
#  ('Q9HCG7', 1),
#  ('Q9NUD5', 1),
#  ('Q9UJC5', 1),
#  ('P12109', 1),
#  ('Q8WWZ1', 1),
#  ('P12271', 1),
#  ('P12272', 1),
#  ('P14543', 1),
#  ('Q7Z6K1', 1),
#  ('Q8N3E9', 1),
#  ('Q8WUA8', 1),
#  ('P12829', 1),
#  ('Q59GG5', 1),
#  ('Q96RP7', 1),
#  ('S4UD68', 1),
#  ('P80075', 1),
#  ('P13535', 1),
#  ('P13640', 1),
#  ('Q96NJ6', 1),
#  ('P80162', 1),
#  ('P59103', 1),
#  ('P40200', 1),
#  ('Q13634', 1),
#  ('Q7RTS1', 1),
#  ('Q92581', 1),
#  ('Q8NBK3', 1),
#  ('P15516', 1),
#  ('Q5JTE5', 1),
#  ('Q9H069', 1),
#  ('Q6ZQR2', 1),
#  ('Q8N100', 1),
#  ('Q9Y5K1', 1),
#  ('Q9NZC9', 1),
#  ('P16066', 1),
#  ('Q9UIG0', 1),
#  ('Q16875', 1),
#  ('P16233', 1),
#  ('Q9NRA1', 1),
#  ('Q9BY71', 1),
#  ('Q9NR96', 1),
#  ('P16415', 1),
#  ('P16519', 1),
#  ('P17030', 1),
#  ('P17040', 1),
#  ('P23582', 1),
#  ('Q9UMS5', 1),
#  ('P17677', 1),
#  ('Q92522', 1),
#  ('Q8IVG9', 1),
#  ('P17947', 1),
#  ('P18065', 1),
#  ('Q13253', 1),
#  ('Q3T8J9', 1),
#  ('P18146', 1),
#  ('Q9Y2B0', 1),
#  ('P19105', 1),
#  ('Q5NV67', 1),
#  ('P19532', 1),
#  ('P19823', 1),
#  ('P20061', 1),
#  ('Q59EC8', 1),
#  ('Q96SQ7', 1),
#  ('Q86YT9', 1),
#  ('Q8IVV8', 1),
#  ('Q8N539', 1),
#  ('Q9HBL6', 1),
#  ('Q16293', 1),
#  ('Q6ZRA3', 1),
#  ('Q96CQ1', 1),
#  ('P21453', 1),
#  ('Q9NYX4', 1),
#  ('Q9Y5S8', 1),
#  ('P55075', 1),
#  ('P50579', 1),
#  ('P22003', 1),
#  ('P22528', 1),
#  ('P28330', 1),
#  ('P22760', 1),
#  ('P22891', 1),
#  ('Q8NHV4', 1),
#  ('P23327', 1),
#  ('P50395', 1),
#  ('Q6UW01', 1),
#  ('P23510', 1),
#  ('P23527', 1),
#  ('P23919', 1),
#  ('P24001', 1),
#  ('Q96TE0', 1),
#  ('P24386', 1),
#  ('Q8WW59', 1),
#  ('Q8TD55', 1),
#  ('Q9H3J6', 1),
#  ('Q9NPB9', 1),
#  ('Q9Y5J5', 1),
#  ('Q5JTC6', 1),
#  ('Q5ZF01', 1),
#  ('Q6P2D7', 1),
#  ('Q8IVL0', 1),
#  ('Q9HCH0', 1),
#  ('UPI0002065BA0', 1),
#  ('P25100', 1),
#  ('P25106', 1),
#  ('P25713', 1),
#  ('Q14CW7', 1),
#  ('Q58A44', 1),
#  ('Q7KZQ1', 1),
#  ('Q7Z3D6', 1),
#  ('Q8N7Y1', 1),
#  ('Q96N28', 1),
#  ('Q9H8E5', 1),
#  ('Q9HAA0', 1),
#  ('Q02252', 1),
#  ('Q0VAK6', 1),
#  ('Q9ULV4', 1),
#  ('Q6ZN30', 1),
#  ('Q7Z591', 1),
#  ('P25929', 1),
#  ('Q6EEV6', 1),
#  ('Q9NRC1', 1),
#  ('Q549C5', 1),
#  ('Q53FG3', 1),
#  ('Q96SM3', 1),
#  ('Q9C0H2', 1),
#  ('Q92527', 1),
#  ('P27544', 1),
#  ('P51530', 1),
#  ('P31644', 1),
#  ('Q96GR4', 1),
#  ('P35414', 1),
#  ('Q9BX73', 1),
#  ('P29279', 1),
#  ('P29374', 1),
#  ('P29377', 1),
#  ('P29459', 1),
#  ('P29558', 1),
#  ('P29803', 1),
#  ('Q9NVV0', 1),
#  ('Q8IUF1', 1),
#  ('Q15173', 1),
#  ('Q96NN9', 1),
#  ('P43630', 1),
#  ('Q14943', 1),
#  ('P30520', 1),
#  ('P32297', 1),
#  ('Q8N328', 1),
#  ('Q9GZZ0', 1),
#  ('P31512', 1),
#  ('P35326', 1),
#  ('Q99218', 1),
#  ('P31944', 1),
#  ('Q9NPC2', 1),
#  ('Q6IAX9', 1),
#  ('Q9H2A1', 1),
#  ('Q96PE2', 1),
#  ('Q96T55', 1),
#  ('Q8NH93', 1),
#  ('Q8TAA1', 1),
#  ('Q96LB4', 1),
#  ('Q96RD1', 1),
#  ('Q9UMX6', 1),
#  ...]

# %%
len(order)
# Out:
# 15367

# %%
y=[]

# %%
for x in range(len(order)-1,len(order)-768,-1):
         y.append(order[x][0])

# %%
y
# Out:
# ['P42858',
#  'P50222',
#  'A8MQ03',
#  'P54253',
#  'P08238',
#  'P62993',
#  'O76024',
#  'Q08379',
#  'Q7Z699',
#  'P07900',
#  'Q8TBB1',
#  'Q99750',
#  'P60410',
#  'Q96HA8',
#  'Q6A162',
#  'P05067',
#  'Q7Z3S9',
#  'Q9NRD5',
#  'Q08117',
#  'Q15323',
#  'Q12933',
#  'P49639',
#  'P22607',
#  'P14373',
#  'Q5JR59',
#  'Q9UMX0',
#  'Q92731',
#  'P12004',
#  'P63279',
#  'Q13520',
#  'P28799',
#  'Q16543',
#  'O75031',
#  'Q04864',
#  'O00560',
#  'P60409',
#  'O60333',
#  'P60369',
#  'Q93062',
#  'P51114',
#  'Q9Y3C5',
#  'P00533',
#  'Q92993',
#  'Q9UHD9',
#  'Q8NHQ1',
#  'O76011',
#  'O60341',
#  'P13473',
#  'Q0VD86',
#  'Q8N6Y0',
#  'Q6UY14',
#  'O14964',
#  'O14901',
#  'Q9UJV3',
#  'P46379',
#  'Q5JX71',
#  'Q8TAP4',
#  'Q9BRK4',
#  'Q92574',
#  'P60411',
#  'Q8IUH5',
#  'Q9NUH8',
#  'Q9UBB9',
#  'Q15047',
#  'Q9H0I2',
#  'P54274',
#  'P14136',
#  'P04792',
#  'P54259',
#  'Q01453',
#  'A6NEM1',
#  'P0DPK4',
#  'Q13077',
#  'P15884',
#  'Q9BVG8',
#  'Q96D03',
#  'Q09019',
#  'P06241',
#  'P55212',
#  'P46108',
#  'P36406',
#  'Q9BYV2',
#  'Q9Y282',
#  'P06396',
#  'Q8WXH2',
#  'Q13148',
#  'O43889',
#  'O75400',
#  'P26371',
#  'O43765',
#  'Q96CV9',
#  'Q9NYB9',
#  'Q8TDT2',
#  'P09429',
#  'Q63ZY3',
#  'Q9NRI5',
#  'P08670',
#  'Q96BA8',
#  'Q07627',
#  'P04637',
#  'Q13064',
#  'Q13137',
#  'Q8N9N5',
#  'Q3LI66',
#  'P51116',
#  'P16333',
#  'Q9BWG6',
#  'Q13526',
#  'O60260',
#  'Q8TAU3',
#  'O43741',
#  'P27986',
#  'Q16659',
#  'P04183',
#  'Q15125',
#  'P25791',
#  'P61981',
#  'P25786',
#  'Q15038',
#  'Q8IUG1',
#  'Q9H8W4',
#  'Q9NRR5',
#  'P0CG48',
#  'P38936',
#  'P50570',
#  'Q8TD31',
#  'P37840',
#  'P11912',
#  'Q8ND90',
#  'P00519',
#  'P04626',
#  'Q9NUX5',
#  'Q16637',
#  'Q9BYB0',
#  'Q92997',
#  'P36897',
#  'Q01844',
#  'Q9Y320',
#  'Q9BQ66',
#  'Q96GM5',
#  'Q9UKT9',
#  'Q9NZD8',
#  'Q15834',
#  'P46934',
#  'P67870',
#  'Q86YD7',
#  'Q13643',
#  'Q8N720',
#  'Q96BE0',
#  'Q9BYQ4',
#  'Q8N5R6',
#  'Q92876',
#  'Q9Y371',
#  'P62826',
#  'Q5T3J3',
#  'P84022',
#  'O43482',
#  'P32242',
#  'Q8TED1',
#  'O43639',
#  'Q15654',
#  'Q63HR2',
#  'P19012',
#  'Q2TAC2',
#  'Q3KNW5',
#  'P78424',
#  'P31749',
#  'Q8IWZ5',
#  'Q13895',
#  'Q9UGI0',
#  'Q9H257',
#  'Q9NX04',
#  'P60328',
#  'Q7Z3Y8',
#  'Q3B820',
#  'Q8IZU0',
#  'Q5JXX7',
#  'P07196',
#  'P60370',
#  'Q9UNE7',
#  'Q9H8Y8',
#  'Q92569',
#  'Q8WV44',
#  'Q6RW13',
#  'Q13485',
#  'P01112',
#  'O95429',
#  'Q96JN2',
#  'Q3SXY8',
#  'Q8N8B7',
#  'O60504',
#  'Q15796',
#  'O95967',
#  'Q02930',
#  'P60331',
#  'O75604',
#  'P29972',
#  'Q14847',
#  'P49841',
#  'Q9NYB0',
#  'Q8IUQ4',
#  'P55040',
#  'Q96SQ5',
#  'Q13573',
#  'Q15797',
#  'P12931',
#  'Q9BYQ3',
#  'Q96EZ8',
#  'P62837',
#  'P61968',
#  'Q86UW9',
#  'Q99471',
#  'Q8TAF8',
#  'Q8WWY3',
#  'P60891',
#  'O15198',
#  'Q96DZ9',
#  'Q05516',
#  'O15162',
#  'Q96N21',
#  'Q16623',
#  'Q15560',
#  'Q03989',
#  'Q9Y649',
#  'O95678',
#  'P59991',
#  'Q13625',
#  'Q9BYR5',
#  'Q92624',
#  'Q09472',
#  'P01023',
#  'Q96Q45',
#  'Q8N5M9',
#  'P78317',
#  'Q9BTE6',
#  'Q8NA61',
#  'P51668',
#  'Q8NEC5',
#  'O15160',
#  'P68431',
#  'Q9UKR5',
#  'P54252',
#  'P48165',
#  'P61978',
#  'P25788',
#  'Q9NZC7',
#  'Q96ED9',
#  'O95273',
#  'Q7Z5P4',
#  'Q8IVD9',
#  'Q99932',
#  'Q14192',
#  'O43463',
#  'Q08426',
#  'Q8N6L0',
#  'Q99816',
#  'Q15645',
#  'P61236',
#  'Q9BVL2',
#  'Q9H2G9',
#  'Q96EQ0',
#  'P43364',
#  'Q5W5X9',
#  'O43559',
#  'P61077',
#  'P25054',
#  'O95751',
#  'P25800',
#  'Q96HB5',
#  'Q9NVV9',
#  'P68104',
#  'Q9Y2D8',
#  'Q96PU5',
#  'Q5UIP0',
#  'P15622',
#  'Q8TAP6',
#  'O95995',
#  'Q14005',
#  'Q9BQY4',
#  'Q8NI38',
#  'Q3SY00',
#  'Q86VR2',
#  'O75558',
#  'P21246',
#  'Q8WXW3',
#  'Q9HCE7',
#  'P40763',
#  'Q8N661',
#  'Q13432',
#  'Q3V5L5',
#  'P54646',
#  'Q13200',
#  'P20073',
#  'O15552',
#  'Q5T749',
#  'Q8IX15',
#  'Q9Y5V3',
#  'P63104',
#  'Q9HC98',
#  'Q9P0T4',
#  'Q9GZY8',
#  'Q96CS2',
#  'Q9NY72',
#  'Q9BUZ4',
#  'Q3LI72',
#  'Q15831',
#  'Q96IW7',
#  'Q08AM6',
#  'O15529',
#  'P15941',
#  'A0A140G945',
#  'Q68D86',
#  'O76003',
#  'P28329',
#  'Q8WW24',
#  'Q8IUC1',
#  'Q9UJX2',
#  'O43711',
#  'Q14957',
#  'P35240',
#  'Q9Y2X8',
#  'P20618',
#  'Q8N1B4',
#  'P03372',
#  'P55081',
#  'Q53FD0',
#  'Q8WWF3',
#  'Q9H6H4',
#  'Q9BWT7',
#  'Q8IUC2',
#  'Q2WGJ6',
#  'P31273',
#  'Q92870',
#  'Q96IK5',
#  'Q969F0',
#  'Q9P2H0',
#  'Q13451',
#  'Q6NT76',
#  'O43186',
#  'Q8IXB3',
#  'P47897',
#  'Q13323',
#  'A5D8V6',
#  'P26367',
#  'P0CG47',
#  'O43597',
#  'Q12873',
#  'P21673',
#  'Q5JST6',
#  'A5PKU2',
#  'Q9H2L4',
#  'P54257',
#  'Q7L273',
#  'B4DYC6',
#  'P50221',
#  'Q9Y250',
#  'P61086',
#  'O95231',
#  'O95994',
#  'Q8N2W9',
#  'B7Z2P9',
#  'P12757',
#  'Q13422',
#  'Q17RB8',
#  'Q9GZT8',
#  'Q92625',
#  'Q8TBE3',
#  'Q7Z6G3',
#  'P01106',
#  'P26641',
#  'O95872',
#  'P86496',
#  'P86479',
#  'P30519',
#  'Q9GZR5',
#  'O95817',
#  'A1L4K1',
#  'O75928',
#  'Q9BYR9',
#  'P0C7H8',
#  'Q7Z417',
#  'Q14973',
#  'P40337',
#  'Q9BVN2',
#  'Q96JP2',
#  'O95295',
#  'P63000',
#  'Q7Z7G2',
#  'P78337',
#  'Q6NUQ1',
#  'P86480',
#  'P08581',
#  'Q9BSI4',
#  'P60953',
#  'Q9HBE1',
#  'Q3SYF9',
#  'P19404',
#  'O00555',
#  'Q6PEX3',
#  'P02766',
#  'P40222',
#  'Q9NQQ7',
#  'O75190',
#  'P38432',
#  'P56545',
#  'P11802',
#  'Q99633',
#  'Q6P1W5',
#  'Q04206',
#  'Q7L5N1',
#  'Q8N448',
#  'P08727',
#  'Q15773',
#  'Q5TD97',
#  'P36508',
#  'Q3LI64',
#  'Q9Y6K9',
#  'O14641',
#  'Q14194',
#  'Q9BYR8',
#  'Q70EL1',
#  'Q5TA81',
#  'Q13113',
#  'Q9BXY8',
#  'O14880',
#  'Q15025',
#  'P0C7T5',
#  'Q6UB99',
#  'Q92764',
#  'Q9BXS5',
#  'O00291',
#  'Q5VU43',
#  'Q96LA8',
#  'Q8IYX8',
#  'Q96EC8',
#  'P86481',
#  'P86478',
#  'Q9Y2J4',
#  'Q9BYQ0',
#  'P58340',
#  'P02545',
#  'Q9HC52',
#  'Q8TAB5',
#  'P12956',
#  'P14678',
#  'P37173',
#  'Q96BR9',
#  'Q6NX45',
#  'P24863',
#  'P60201',
#  'Q9NQL9',
#  'O43609',
#  'Q15811',
#  'Q14203',
#  'Q5VTD9',
#  'Q9BZE0',
#  'Q7Z3K3',
#  'P09234',
#  'P21964',
#  'Q8IYI6',
#  'Q9Y266',
#  'Q06455',
#  'Q99459',
#  'Q16539',
#  'P51687',
#  'O14503',
#  'P27797',
#  'P17252',
#  'Q8N5A5',
#  'Q9NSC5',
#  'P04049',
#  'Q6L8G9',
#  'O75716',
#  'Q8IXK0',
#  'Q96RU7',
#  'Q13387',
#  'Q96BZ8',
#  'Q16512',
#  'P36957',
#  'Q14457',
#  'P50402',
#  'P29474',
#  'Q15742',
#  'Q9H2K0',
#  'Q9UI47',
#  'Q96EG3',
#  'P62805',
#  'P10275',
#  'Q9H0C1',
#  'Q9P2K3',
#  'Q2TBE0',
#  'Q99757',
#  'Q9BZW7',
#  'A0A024R8L2',
#  'P52292',
#  'Q9GZM8',
#  'Q5RL73',
#  'Q8IWU4',
#  'Q52LG2',
#  'P21333',
#  'Q9NZM3',
#  'Q9UER7',
#  'P57075',
#  'P62942',
#  'P16284',
#  'Q8IYA8',
#  'Q96B02',
#  'Q969T4',
#  'O95214',
#  'Q53EZ4',
#  'Q6NYC8',
#  'P78358',
#  'P0CG20',
#  'P21145',
#  'Q9UBU9',
#  'Q96A09',
#  'Q01850',
#  'Q9BYR6',
#  'Q9NS64',
#  'P19174',
#  'Q8N7W2',
#  'Q96KM6',
#  'Q5T7P3',
#  'Q8TD10',
#  'P26196',
#  'Q5SR56',
#  'Q9H9D4',
#  'Q9UQM7',
#  'P37198',
#  'P63165',
#  'P24593',
#  'Q8NBJ4',
#  'Q9UI14',
#  'B0QZE7',
#  'P00540',
#  'O43167',
#  'Q14525',
#  'Q9NR31',
#  'Q8IYF3',
#  'P19397',
#  'Q92567',
#  'P27105',
#  'Q86WT6',
#  'P52597',
#  'O95070',
#  'P31948',
#  'P62136',
#  'Q9HBZ2',
#  'Q00987',
#  'Q96NT3',
#  'Q5T754',
#  'Q3SY46',
#  'O00308',
#  'Q9Y680',
#  'P15822',
#  'Q58EX7',
#  'P63010',
#  'Q9BYR7',
#  'Q9NZG7',
#  'P68400',
#  'Q8NA54',
#  'Q8NE01',
#  'Q92734',
#  'Q86VP1',
#  'P54725',
#  'P30273',
#  'Q9Y2M5',
#  'Q8TBE0',
#  'P43360',
#  'O14645',
#  'P31321',
#  'Q9UBU8',
#  'Q15041',
#  'P53041',
#  'Q5VVX9',
#  'Q8WWB5',
#  'Q9P2A4',
#  'Q96A72',
#  'P45984',
#  'O95471',
#  'Q9H788',
#  'Q9Y5B8',
#  'P28482',
#  'P27658',
#  'Q96MT8',
#  'Q12797',
#  'Q99081',
#  'Q96GN5',
#  'P60371',
#  'Q9HAU5',
#  'P02649',
#  'Q14145',
#  'Q12837',
#  'Q3LI76',
#  'P49768',
#  'P00441',
#  'Q15915',
#  'Q9BYQ6',
#  'Q9BYU1',
#  'P41219',
#  'Q14696',
#  'P54652',
#  'Q9Y3Q8',
#  'Q9HAU4',
#  'Q9NQX0',
#  'Q9NPJ6',
#  'Q9NUL5',
#  'P49901',
#  'O76015',
#  'Q7Z3I7',
#  'Q5QGT7',
#  'Q8TDX7',
#  'Q01658',
#  'Q96MY7',
#  'Q8N3L3',
#  'Q7Z5V6',
#  'Q6ZNG0',
#  'P51965',
#  'P13805',
#  'Q5BVD1',
#  'Q5TA78',
#  'Q5T7P2',
#  'Q8N5M1',
#  'Q9UNK0',
#  'A2RU14',
#  'Q8IYE0',
#  'A0A096LP49',
#  'Q96MV1',
#  'P01100',
#  'O95870',
#  'Q9HB71',
#  'Q15554',
#  'O43561',
#  'Q13352',
#  'Q9UHD4',
#  'Q4KMG9',
#  'O95363',
#  'O43464',
#  'Q9H6L4',
#  'Q96KQ4',
#  'P40692',
#  'Q96AP0',
#  'Q04724',
#  'O95183',
#  'Q04941',
#  'Q9NS23',
#  'Q9C086',
#  'O43189',
#  'Q9BRI3',
#  'Q6ZRY4',
#  'Q9UBR4',
#  'Q8IY31',
#  'Q8IVT4',
#  'Q14119',
#  'Q96PN8',
#  'P62873',
#  'Q14790',
#  'P38398',
#  'Q96B26',
#  'O75791',
#  'Q92905',
#  'O00238',
#  'Q9UKJ5',
#  'Q9H5Z6',
#  'Q5TCM9',
#  'Q5T751',
#  'Q96PV4',
#  'Q5BKX5',
#  'Q9H0Q3',
#  'P80188',
#  'P15976',
#  'Q9Y2V7',
#  'Q7Z4V0',
#  'Q53G59',
#  'Q8WW34',
#  'O14744',
#  'Q96I34',
#  'O75925',
#  'Q6PF18',
#  'O14633',
#  'Q9NQT4',
#  'Q3LI70',
#  'Q14764',
#  'Q9Y2P0',
#  'Q969G3',
#  'Q9H0E2',
#  'Q05086',
#  'P0DP25',
#  'Q86Z20',
#  'Q13155',
#  'P04439',
#  'Q8WZ42',
#  'Q9NPL8',
#  'Q8WUW1',
#  'P61088',
#  'Q96FW1',
#  'P55072',
#  'Q9BYR3',
#  'Q5VWN6',
#  'Q96CN9',
#  'O75593',
#  'Q96HE8',
#  'Q9Y5Q9',
#  'A8MV65',
#  'Q8IZU1',
#  'O95257',
#  'Q14103',
#  'Q13021',
#  'Q14129',
#  'P48730',
#  'P55061',
#  'Q99732',
#  'Q9NP66',
#  'Q9Y3C7',
#  'P04406',
#  'P62195',
#  'Q9H190',
#  'P17028',
#  'Q6FII3',
#  'Q8IYR0',
#  'P08631',
#  'Q8TDC0',
#  'Q6P2Q9',
#  'Q14802',
#  'O75934',
#  'Q00534',
#  'P42772',
#  'P22455',
#  'O75386',
#  'P11142',
#  'Q96JM7',
#  'Q6VMQ6',
#  'Q6ZNA4',
#  'Q99873',
#  'Q9UGL9',
#  'Q92824',
#  'P15151',
#  'Q9Y383',
#  'Q9NWS9',
#  'Q9BT49',
#  'O76064',
#  'Q86VK4',
#  'Q86X02',
#  'P62258',
#  'Q8TAE8',
#  'Q9NWB1',
#  'Q9GZV8',
#  'Q96F15',
#  'Q9NRQ2',
#  'Q6NTF9',
#  'Q8N205',
#  'Q9BQA9',
#  'Q9Y4K3',
#  'P27449',
#  'P60520',
#  'Q8N5K1',
#  'Q9Y223',
#  'Q5TA76',
#  'P07947',
#  'Q7Z6R9',
#  'O43809',
#  'Q9HCM9',
#  'P43628',
#  'P56524',
#  'P53365',
#  'O43251',
#  'O00303']
